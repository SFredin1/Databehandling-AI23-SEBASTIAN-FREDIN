# %%
import pandas as pd
import seaborn as sns

# %%
titanic = pd.read_json("../Data/titanic_encoded.json")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500       0.0  Third
# 1         1       1  female  38.0      1      0  71.2833       1.0  First
# 2         1       3  female  26.0      0      0   7.9250       0.0  Third
# 3         1       1  female  35.0      1      0  53.1000       0.0  First
# 4         0       3    male  35.0      0      0   8.0500       0.0  Third
#
#      who  adult_male  deck  embark_town alive  alone
# 0    man        True  None  Southampton    no  False
# 1  woman       False     C    Cherbourg   yes  False
# 2  woman       False  None  Southampton   yes   True
# 3  woman       False     C  Southampton   yes  False
# 4    man        True  None  Southampton    no   True

# %% [markdown]
# ## Correlation analysis
# Correlation analysis is a statistical technique used to examine the strength and direction of the relationship between two or more variables. It involves analyzing the degree to which changes in one variable are associated with changes in another variable.
#
# ### Pandas .corr() method
# Calculates the correlation coefficents between all pairs of features in a dataframe, and returns a new dataframe with where the number of rows and columns both match the number of columns in the input df.

# %%
correlation_matrix = titanic.corr()
correlation_matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\Documents\GitHub\Python-Sebastian-Fredin\Databehandling-AI23-SEBASTIAN-FREDIN\Code_Alongs\L010_Correlation_Analysis.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/GitHub/Python-Sebastian-Fredin/Databehandling-AI23-SEBASTIAN-FREDIN/Code_Alongs/L010_Correlation_Analysis.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> correlation_matrix = titanic.corr()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/GitHub/Python-Sebastian-Fredin/Databehandling-AI23-SEBASTIAN-FREDIN/Code_Alongs/L010_Correlation_Analysis.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> correlation_matrix
#
# File c:\Users\user\.virtualenvs\Databehandling-AI23-SEBASTIAN-FREDIN-Q4_aLbq2\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\user\.virtualenvs\Databehandling-AI23-SEBASTIAN-FREDIN-Q4_aLbq2\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\user\.virtualenvs\Databehandling-AI23-SEBASTIAN-FREDIN-Q4_aLbq2\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\user\.virtualenvs\Databehandling-AI23-SEBASTIAN-FREDIN-Q4_aLbq2\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'male'
