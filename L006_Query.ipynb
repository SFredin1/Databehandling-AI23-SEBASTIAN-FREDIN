# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np

# %%
floats = pd.DataFrame

# %%
# Creating bool mask for column "B"
floats["B"] >= 0

# Selecting all rows where

# %% [markdown]
# ## Querying data
# Filtering rows based on values of certain attributes can be done either with bool index or pandas query method

# %%
autos = pd.read_json("../Data/new_autos.json")
autos.head()
# Out:
#   aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0        std  convertible  3.47        21                9.0         2548
# 1        std  convertible  3.47        21                9.0         2548
# 2        std    hatchback  2.68        19                9.0         2823
# 3        std        sedan  3.19        24               10.0         2337
# 4        std        sedan  3.19        18                8.0         2824
#
#   drive-wheels engine-location  engine-size engine-type  ...         make  \
# 0          rwd           front          130        dohc  ...  alfa-romero
# 1          rwd           front          130        dohc  ...  alfa-romero
# 2          rwd           front          152        ohcv  ...  alfa-romero
# 3          fwd           front          109         ohc  ...         audi
# 4          4wd           front          136         ohc  ...         audi
#
# ...

# %%
autos[autos["make"] == "Volvo"]
autos.query("make == 'Volvo'")

autos[autos["engine-size"] <= 140]
#autos.query("'engine-size' <= 140")

autos[(autos["make"] == "volvo") & (autos["engine-size"] <= 140)]

autos.query("make == 'volvo' and 'engine-size' <= 140")
autos.query("make == 'volvo' or 'engine-size' <= 140")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\user\Documents\GitHub\Python-Sebastian-Fredin\Databehandling-AI23-SEBASTIAN-FREDIN\L006_Query.ipynb Cell 7 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/GitHub/Python-Sebastian-Fredin/Databehandling-AI23-SEBASTIAN-FREDIN/L006_Query.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> #autos.query("'engine-size' <= 140")
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/GitHub/Python-Sebastian-Fredin/Databehandling-AI23-SEBASTIAN-FREDIN/L006_Query.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> autos[(autos["make"] == "volvo") & (autos["engine-size"] <= 140)]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/GitHub/Python-Sebastian-Fredin/Databehandling-AI23-SEBASTIAN-FREDIN/L006_Query.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> autos.query("make == 'volvo' and 'engine-size' <= 140")
# ...

# %%
import seaborn as sns

sns.relplot(x="engine_size", y="price" data=autos.query(make == "Volvo"))

# %% [markdown]
# ## Sorting DataFrame
# DataFrames can be sorted using the .sort_values() method
#
# Parameters:
# - **by** Column or list of columns
# - **ascending** Option. Default=True

# %%
autos.sort_values(by=["make", "engine-size"], ascending=[False, True])
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 198      turbo        sedan  3.62        17                7.5         3045
# 199      turbo        wagon  3.62        17                7.5         3157
# 194        std        sedan  3.78        23                9.5         2912
# 195        std        wagon  3.78        23                9.5         3034
# 196        std        sedan  3.78        24                9.5         2935
# ..         ...          ...   ...       ...                ...          ...
# 6          std        sedan  3.19        19                8.5         2844
# 7          std        wagon  3.19        19                8.5         2954
# 0          std  convertible  3.47        21                9.0         2548
# 1          std  convertible  3.47        21                9.0         2548
# 2          std    hatchback  2.68        19                9.0         2823
#
# ...
